# %% [markdown]
# ## Precedence of operators

# %% [markdown]
# ### BODMAS
#
# > Bracket Off Division Multiplication Addition Subtraction

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
orders = ["biryani","icecream","dosa"]

# %%
# Two operators
"biryani" and "dosa" in orders # =>"biryani" and ("dosa in orders")
# Out:
# True

# %%
"biryani" or "icecream" in orders
# Out:
# 'biryani'

# %%
"biryani" or "icecream" and "dosa" or "1213" and "t" in "teeth"
# Out:
# 'biryani'

# %%
6/2 + 3**4
# Out:
# 84.0

# %% [markdown]
# ### Associativity

# %%
"karan" and "a" and "b" or "c" and "d" or "a" and "s"
# Out:
# 'b'

# %%
2 ** 3 ** 2 #Exception in associativity
# Out:
# 512
